# %%
print('Im working')
# Out:
# Im working

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import statsmodels.api as sm
import seaborn as sns
import scipy.stats as stats
# Imports for hierarchical clustering
from scipy.cluster.hierarchy import dendrogram, linkage  
from sklearn import preprocessing
from scipy.spatial import distance
from tqdm import tqdm
import plotly.tools as tls

# %%
# Read the dataset
df = pd.read_csv("data/data3.csv")

# %%
# method to sample a dataset (hardcoded seed for randomized selection, see alternatives in comment)
def get_sample_from_dataset(prop, dataset):
    # randomly define sample from dataset
    # good seeds to try: 13, 42, 1123, 5813, 213455
    #np.random.seed(seed=42)
    # We are going to use bootstrapping
    sample_proportion =  prop
    dataset_size = len(dataset)
    sample_size = sample_proportion * dataset_size
    # perform scaling on the dataset
    dataset = preprocessing.scale(df)
    # Turn into a pandas array again
    dataset = pd.DataFrame({'Column1':dataset[:,0],'Column2':dataset[:,1],'Column3':dataset[:,2]})
    
    print("The sample size we are going to use will be: "+ str(sample_size))
    # Run the sampling
    chosen_idx = np.random.choice(dataset_size, replace=False, size=int(sample_size))
    sampled_dataset =  dataset.iloc[chosen_idx]
    print("The new shape of the sampled dataset is: " + str(sampled_dataset.values.shape))
    return sampled_dataset

# %%
np.random.seed(seed=42)

# Get a sample from the data-set to run hierarchical clustering
sampled_dataset = get_sample_from_dataset(0.05, df)

# Perform Linkage on the sampled dataset
arrayFormDf = sampled_dataset.values
 
linked = linkage(arrayFormDf, 'single')

dendrogram(linked,  
            truncate_mode='lastp',
            p=12,
            leaf_rotation=45.,
            leaf_font_size=15.,
            show_contracted=True)
plt.title('Truncated Hierarchical Clustering Dendogram')
plt.xlabel('Cluster Label')
plt.ylabel('Distance')
plt.show()
# Out:
# The sample size we are going to use will be: 15000.0
# The new shape of the sampled dataset is: (15000, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
#%matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

print(arrayFormDf[:,0])
sequence_containing_x_vals = list(arrayFormDf[:,0])
sequence_containing_y_vals = list(arrayFormDf[:,1])
sequence_containing_z_vals = list(arrayFormDf[:,2])

ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals, sequence_containing_z_vals)
fig.set_size_inches(10, 10, forward=True)

plt.show()
# Out:
# [-0.84493501 -0.66075807  0.41454324 ...  0.34119644  0.29757433
#   0.62304273]

# %%
# Generate a random vector
# Set seed
np.random.seed(seed=67)
sampled_dataset = get_sample_from_dataset(0.001, df)

# Calculation of the random vector
hopkinsVector = generateRandomVector(3, sampled_dataset.values)

#%matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

sequence_containing_x_vals = list(hopkinsVector[:,0])
sequence_containing_y_vals = list(hopkinsVector[:,1])
sequence_containing_z_vals = list(hopkinsVector[:,2])

ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals, sequence_containing_z_vals)
fig.set_size_inches(10, 10, forward=True)

plt.show()
# Out:
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)

# %%
np.random.seed(seed=42)

# Helper function we are going to use to generate the Hopkins Stat"
def generateRandom(min, max, n):
    # Call NP function for unif random values
    randomArray = np.random.uniform(min,max,n)
    return randomArray
    
# Function to determine the eucliean N-distance between 2 points"
def getDistance(i,j):
    dst = distance.euclidean(i, j)
    return dst
    
# Function to generate a random Vector for the hopkins stat"
def generateRandomVector(dimensions, arrayFormData):
    # Calculate size of the data
    size = len(arrayFormData)
    minValues = []
    maxValues = []
    randomVector = np.zeros(shape=(size,dimensions))
    for i in range(dimensions):
        #Calculate the min and max values
        currentMinValue = min(arrayFormData[:,i])
        currentMaxValue = max(arrayFormData[:,i])
    
        # Generate random numbers between min-max"
        currentComponent = generateRandom(currentMinValue, currentMaxValue, size)
        #Apend to result
        randomVector[:,i] = currentComponent
    
    return randomVector

# Hopkins Stat
def hopkinsStat(uniformVector, arrayFormDf):
    # Hopkins Stat code
    # Initialize denom at 0 
    numerator = 0

    for j in range(len(arrayFormDf)):
        # Set current Min to something huge
        currentMin = 10000

        for i in range(len(arrayFormDf)):    
            # Calculate distance out of a point
            dst = getDistance(uniformVector[j], arrayFormDf[i])
            if dst < currentMin:
                currentMin = dst

        numerator = numerator + currentMin

    # Initialize the num at 0
    denominator = 0


    for j in range(len(arrayFormDf)):
        # Set the current Min to something huge
        currentMin = 1000
        for i in range(len(arrayFormDf)):
            # If i equial j skip
            if i == j:
                continue

            # Calculate distance out of a point
            dst = getDistance(arrayFormDf[j], arrayFormDf[i])
            if dst < currentMin:
                currentMin = dst

        denominator = denominator + currentMin
    
    # Calculate it!
    hopkinsStat = numerator / (numerator + denominator)
    return hopkinsStat

# %%
# Calculate the hopkins stat
# Generate a random vector
# Set seed
np.random.seed(seed=67)
sampled_dataset = get_sample_from_dataset(0.001, df)

# Calculation of the random vector
hopkinsVector = generateRandomVector(3, sampled_dataset.values)

results = []
for i in range(150):
    np.random.seed(seed=(42 + i))

    # Get a sample from the data-set to run the hopkins stat
    sampled_dataset = get_sample_from_dataset(0.001, df)
    arrayFormSample = sampled_dataset.values
    
    # Print to see progress
    print("Iteration: " + str(i+1))

    ## CALCULATION OF THE HOPKINS STAT ##
    result = hopkinsStat(hopkinsVector, arrayFormSample)
    
    # Apend to the results array
    results.append(result)

print(results)

# Call Hopkins Function
#result = hopkinsStat(hopkinsVector, arrayFormSample)
#print(result)
# Out:
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 1
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 2
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 3
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 4
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 5
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 6
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 7
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 8
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 9
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 10
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 11
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 12
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 13
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 14
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 15
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 16
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 17
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 18
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 19
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 20
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 21
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 22
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 23
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 24
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 25
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 26
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 27
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 28
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 29
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 30
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 31
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 32
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 33
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 34
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 35
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 36
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 37
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 38
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 39
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 40
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 41
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 42
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 43
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 44
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 45
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 46
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 47
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 48
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 49
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 50
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 51
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 52
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 53
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 54
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 55
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 56
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 57
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 58
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 59
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 60
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 61
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 62
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 63
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 64
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 65
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 66
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 67
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 68
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 69
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 70
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 71
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 72
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 73
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 74
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 75
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 76
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 77
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 78
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 79
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 80
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 81
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 82
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 83
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 84
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 85
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 86
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 87
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 88
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 89
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 90
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 91
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 92
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 93
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 94
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 95
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 96
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 97
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 98
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 99
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 100
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 101
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 102
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 103
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 104
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 105
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 106
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 107
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 108
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 109
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 110
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 111
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 112
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 113
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 114
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 115
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 116
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 117
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 118
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 119
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 120
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 121
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 122
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 123
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 124
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 125
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 126
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 127
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 128
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 129
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 130
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 131
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 132
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 133
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 134
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 135
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 136
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 137
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 138
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 139
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 140
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 141
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 142
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 143
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 144
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 145
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 146
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 147
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 148
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 149
# The sample size we are going to use will be: 300.0
# The new shape of the sampled dataset is: (300, 3)
# Iteration: 150
# [0.9040672208006794, 0.8947776982450387, 0.9020739007992682, 0.8966531434887545, 0.8969456890147806, 0.8954861933946557, 0.9008613356737893, 0.8902850525815177, 0.8976240059487622, 0.8942391989823694, 0.8954323281213494, 0.9011015319001593, 0.8977773442566354, 0.9027690045622889, 0.89627800153273, 0.8977164819985414, 0.8916096145544619, 0.8932344810064737, 0.8931076908227051, 0.9010645575603088, 0.9034100707233621, 0.8936411222205043, 0.9059727386395477, 0.8966027845771065, 0.8986105148427206, 0.8953448698381908, 0.9021458690947701, 0.8961994168621098, 0.9031643112552753, 0.8953883817852065, 0.8957143161777262, 0.8968854650233741, 0.9009319514680093, 0.8958086754608117, 0.8991608787165688, 0.9042451328541471, 0.9007947016467889, 0.8948210152842093, 0.8960509210747694, 0.9000788394369162, 0.9010820610189672, 0.8919339241105502, 0.8961555520297455, 0.8934768781453479, 0.9013681921769384, 0.9050692423381229, 0.8996345000587218, 0.9056295185406343, 0.8993120047317239, 0.8942569360362078, 0.9043562711205912, 0.9056862436971228, 0.8966422095640976, 0.9002107316549216, 0.8957142728557224, 0.896496779126443, 0.90440899733138, 0.8989529727495041, 0.8968019310711599, 0.8953365197623468, 0.893332367545226, 0.9001964022520071, 0.9032223820130721, 0.8930717176379473, 0.8941325334079363, 0.896727532691642, 0.9018219848424678, 0.9007615203701413, 0.8997460751692203, 0.9038507783938289, 0.8999687844303473, 0.8928795043580458, 0.903932402711949, 0.8924288279070984, 0.9032463155217892, 0.8934432879347105, 0.8980310278633983, 0.890385017208664, 0.8877884522895224, 0.8922000536381733, 0.8989725258385557, 0.9001833987914539, 0.9017068624821903, 0.8940793964472484, 0.9012368111951413, 0.897695810303366, 0.8996461234254263, 0.8925350411218699, 0.8986422217188518, 0.9064993331489922, 0.8977151605902454, 0.8992403742139308, 0.9026888540728943, 0.9019863451027003, 0.8909853947044128, 0.8958050229331362, 0.9026579623025414, 0.897735963801009, 0.9014194737838793, 0.9039682658703945, 0.9050282422406006, 0.8946892160085704, 0.8977668820905478, 0.8956917281870295, 0.8959005929307793, 0.8980312778112032, 0.8938763567595929, 0.9010551574245016, 0.8940870778985264, 0.8945567066442919, 0.8937349419418218, 0.8952623479628865, 0.8970783960693522, 0.8938386456959142, 0.8990404258216403, 0.9002438880240484, 0.8970114653748444, 0.8960492658664339, 0.8971921594485228, 0.900239156120433, 0.9033036891445589, 0.8967017719365779, 0.8927786564242235, 0.8995939422910341, 0.903201572398383, 0.9014875829139858, 0.8960954166172356, 0.8906799051234754, 0.904444840138041, 0.895604333593783, 0.8998364340299531, 0.8998695091734922, 0.8959489731708046, 0.9000628387369092, 0.9003039844401465, 0.8944093559954452, 0.9031046289846746, 0.8965549833704067, 0.905347677730238, 0.8949011669796864, 0.8967046839166752, 0.898373659970362, 0.8909857051021264, 0.8993560838703603, 0.8881002537513975, 0.8901591919925618, 0.896883354073443, 0.895188420440436, 0.8933818549331437, 0.8914051235494818]

# %%
# Plot a histogram with the results of the hopkins stat vector
plt.hist(results)
plt.title("Hopkins Stat Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

fig = plt.gcf()

# %%
#######DISREGARD THIS CODE ##############
uniformVector = generateRandomVector(3, arrayFormDf)
#getDistance(arrayFormDf[0], uniformVector[0])

# Hopkins Stat code
# Initialize denom at 0 
denominator = 0

for j in tqdm(range(150)):
    # Set current Min to something huge
    currentMin = 10000
    
    for i in range(len(arrayFormDf)):    
        # Calculate distance out of a point
        dst = getDistance(uniformVector[j], arrayFormDf[i])
        if dst < currentMin:
            currentMin = dst
            
    denominator = denominator + currentMin

# Initialize the num at 0
numerator = 0


for j in tqdm(range(150)):
    # Set the current Min to something huge
    currentMin = 1000
    for i in range(len(arrayFormDf)):
        # If i equial j skip
        if i == j:
            continue
            
        # Calculate distance out of a point
        dst = getDistance(arrayFormDf[j], arrayFormDf[i])
        if dst < currentMin:
            currentMin = dst
            
    numerator = numerator + currentMin
    
print(numerator)
hopkinsStat = numerator / (numerator + denominator)
print(hopkinsStat)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 150/150 [00:41<00:00,  3.54it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 150/150 [00:34<00:00,  4.57it/s]
# 5.257467149150353
# 0.02484456657371426

# %%
dst = getDistance(arrayFormDf[0], arrayFormDf[0])
